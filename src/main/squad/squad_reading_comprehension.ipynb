# %%
from typing import List, Tuple, NamedTuple
from collections import namedtuple
import sys
import math
import torch
from torch.utils.data.dataloader import DataLoader, default_collate
from torch.utils.checkpoint import checkpoint
from tqdm import tqdm

sys.path.append("/floyd/home")

from src.common.neural_net_param_utils import normal_weight_init, print_gradients
from src.data.instance.instance import SquadTensorInstance
from src.tokenization.pretrained_bert_tokenizer import PretrainedBertTokenizer
from src.data.dataset.datasetreaders import SquadReader
from src.data.dataset.dataset import SquadDatasetForBert
from src.modules.question_answering_modules import BertQuestionAnsweringModule, BertQuestionAnsweringModuleSimplified
from torch.nn.functional import pad
from torch.autograd import Variable
from pytorch_pretrained_bert.optimization import BertAdam

dataset_data_file_path: str = "/floyd/input/squad"

training_data_file_path: str = dataset_data_file_path + "/train-v2.0.json"
dev_data_file_path: str = dataset_data_file_path + "/dev-v2.0.json"

# training_data_file_path: str = dataset_data_file_path + "/sample.json"
# dev_data_file_path: str = dataset_data_file_path + "/sample.json"



# the number of epochs to train the model for
NUM_EPOCHS: int = 2

# batch size to use for training. The default can be kept small when using gradient accumulation. However, if
# use_gradient_accumulation were to be False, it's best to use a reasonably large batch size
BATCH_SIZE: int = 5

# max-allowed token sequence length for pretrained-model
MAX_ALLOWED_BERT_TOKEN_SEQUENCE_LENGTH: int = 512

use_checkpointing: bool = False
use_gradient_accumulation: bool = True

# num of gradient accumulation steps. Will have no effect if use_gradient_accumulation is false
NUM_GRADIENT_ACCUMULATION_STEPS: int = 10


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


SquadTensorTuple: NamedTuple = namedtuple('SquadTensorTuple', ['token_ids', 'segment_ids', 'answer_start_index',
                                                               'answer_end_index', 'attention_mask'])

pretrained_bert_tokenizer = PretrainedBertTokenizer('bert-base-uncased')

answer_start_marker = "π"
answer_end_marker = "ß"

answer_start_marker_with_spaces: str = " %s " % answer_start_marker
answer_end_marker_with_spaces: str = " %s " % answer_end_marker


def collate_with_padding(batch):
    if not isinstance(batch[0], SquadTensorInstance):
        return default_collate(batch)

    max_length_instance = max(batch, key = lambda batch_item: batch_item.token_ids.size()[0])
    max_length = max_length_instance.token_ids.size()[0]
    batch_as_tensor_tuples = []
    for instance in batch:
        instance_length = instance.token_ids.size()[0]
        padding_size = max_length - instance_length
        instance.token_ids = pad(instance.token_ids, (0, padding_size))
        instance.segment_ids = pad(instance.segment_ids, (0, padding_size))
        instance.attention_mask = torch.tensor([1] * instance_length + [0] * padding_size, device = device)
        batch_as_tensor_tuples.append(
            SquadTensorTuple(instance.token_ids, instance.segment_ids, instance.answer_indices[0].item(),
                             instance.answer_indices[1].item(),
                             instance.attention_mask))

    return default_collate(batch_as_tensor_tuples)


def get_squad_dataset_from_file(file_path: str) -> SquadDatasetForBert:
    instances = SquadReader.read(file_path)
    squad_dataset_list: List = []
    num_skipped_instances: int = 0

    for squad_qa_instance_as_dict in instances:
        if 'span_start' not in squad_qa_instance_as_dict:
            continue

        span_start_char_index: int = squad_qa_instance_as_dict['span_start']
        span_end_char_index: int = squad_qa_instance_as_dict['span_end']

        passage_text = squad_qa_instance_as_dict['passage']

        # here we are simply inserting answer start and end markers so that after tokenization we can still track
        # the answer boundaries
        passage_text_for_tokenization = passage_text[:span_start_char_index] + answer_start_marker_with_spaces + \
                                        passage_text[
                                        span_start_char_index: span_end_char_index] + answer_end_marker_with_spaces + \
                                        passage_text[span_end_char_index:]

        passage_tokens = pretrained_bert_tokenizer.tokenize(passage_text_for_tokenization)
        question_tokens = pretrained_bert_tokenizer.tokenize(squad_qa_instance_as_dict['question'])

        answer_start_marker_index = passage_tokens.index(answer_start_marker)
        answer_end_marker_index = passage_tokens.index(answer_end_marker)

        # let's remove the answer markers now
        passage_tokens = passage_tokens[:answer_start_marker_index] + \
                         passage_tokens[answer_start_marker_index + 1: answer_end_marker_index] + \
                         passage_tokens[answer_end_marker_index + 1:]

        answer_span_start_token_index: int = answer_start_marker_index + len(question_tokens)

        # removing the start marker, shifts the answer towards the start by an additional index,
        # hence -2 as opposed to -1
        answer_span_end_token_index: int = answer_end_marker_index - 2 + len(question_tokens)

        all_tokens = question_tokens + passage_tokens

        if len(all_tokens) > MAX_ALLOWED_BERT_TOKEN_SEQUENCE_LENGTH:
            num_skipped_instances += 1
            continue

        all_token_ids = pretrained_bert_tokenizer.convert_tokens_to_ids(all_tokens)
        all_segment_ids = [0 for question_token in question_tokens] + [1 for passage_token in passage_tokens]
        answer_indices = (answer_span_start_token_index, answer_span_end_token_index)

        instance_tensor = SquadTensorInstance(torch.tensor(all_token_ids, dtype = torch.long, device = device),
                                              torch.tensor(all_segment_ids, dtype = torch.long, device = device),
                                              torch.tensor(answer_indices, dtype = torch.long, device = device))

        squad_dataset_list.append(instance_tensor)

        # print(passage_tokens)
        # print(question_tokens)
        # print(squad_qa_instance_as_dict['answer'])

    return SquadDatasetForBert(squad_dataset_list), num_skipped_instances


train_dataset, num_skipped_training_instances = get_squad_dataset_from_file(training_data_file_path)
train_dataloader = DataLoader(train_dataset, batch_size = BATCH_SIZE, collate_fn = collate_with_padding)

test_dataset, num_skipped_test_instances = get_squad_dataset_from_file(dev_data_file_path)
test_dataloader = DataLoader(test_dataset, batch_size = BATCH_SIZE, collate_fn = collate_with_padding)

print("num skipped training instances: " + str(num_skipped_training_instances))
print("num skipped test instances: " + str(num_skipped_test_instances))

bert_qa_module = BertQuestionAnsweringModuleSimplified(device = device,
                                             named_param_weight_initializer = normal_weight_init)

bert_qa_module.to(device)

print("num named parameters: " + str(len([p for n, p in bert_qa_module.named_parameters()])))

# this makes sure checkpointing still calculates gradients,
# refer to https://discuss.pytorch.org/t/checkpoint-with-no-grad-requiring-inputs-problem/19117/11
unused_tensor = torch.zeros((2, 2), requires_grad = True).to(device)

if use_checkpointing:
    # refer to https://github.com/prigoyal/pytorch_memonger/blob/master/tutorial/Checkpointing_for_PyTorch_models.ipynb
    # dropout is not recommended while using checkpointing.
    # Note that BERT also uses layer-norm internally. So far, disabling that hasn't been tried in checkpointing mode
    bert_qa_module.bert_model.config.attention_probs_dropout_prob = 0
    bert_qa_module.bert_model.config.hidden_dropout_prob = 0

loss_function = torch.nn.CrossEntropyLoss()

num_train_iterations = NUM_EPOCHS * math.ceil(len(train_dataset) / BATCH_SIZE)
optimizer = BertAdam(bert_qa_module.parameters(), lr = 5e-5, warmup = 0.1, t_total = num_train_iterations)

batch_num: int = 0

for epoch in tqdm(range(NUM_EPOCHS)):
    print("inside training loop")
    for data_item in train_dataloader:

        answer_start_index_batch_as_matrix = data_item[2].unsqueeze(dim = 1).to(device = device)
        answer_end_index_batch_as_matrix = data_item[3].unsqueeze(dim = 1).to(device = device)

        # Note that pytorch's checkpoint method does not imply the traditional meaning of checkpointing
        # (which generally indicates saving a model/process to be resumed later). Instead, it's a
        # process to avoid memory consumption (caused by reverse mode auto-differentiation) at the cost of performance.
        # More here: https://pytorch.org/docs/stable/checkpoint.html
        # checkpointing was simply added to ensure the model can run on a cpu or low-cost GPUs, else
        # the BERT transformer makes a 12 GB Tesla K80 run out of memory.

        if use_checkpointing:
            bert_model_output: Tuple[torch.Tensor, torch.Tensor] = checkpoint(bert_qa_module, data_item[0],
                                                                              data_item[1], data_item[4], unused_tensor)
        else:
            bert_model_output: Tuple[torch.Tensor, torch.Tensor] = bert_qa_module(input_ids = data_item[0],
                                                                                  token_type_ids = data_item[1],
                                                                                  attention_mask = data_item[4],
                                                                                  output_all_encoded_layers = False)

        batch_num += 1

        answer_start_indices_chosen_by_model = torch.squeeze(torch.topk(bert_model_output[0], 1, dim = 1)[1])
        answer_end_indices_chosen_by_model = torch.squeeze(torch.topk(bert_model_output[1], 1, dim = 1)[1])

        # start index loss
        answer_start_index_loss = loss_function(bert_model_output[0], answer_start_index_batch_as_matrix)

        # answer end-index loss
        answer_end_index_loss = loss_function(bert_model_output[1], answer_end_index_batch_as_matrix)

        total_loss = answer_start_index_loss + answer_end_index_loss

        if use_gradient_accumulation:
            total_loss = total_loss / NUM_GRADIENT_ACCUMULATION_STEPS

        total_loss.backward()

        if batch_num % 8000 == 0:
            print("output calculation done for batch#: " + str(batch_num))
            print("total loss: " + str(total_loss.data.item()))
            print_gradients(bert_qa_module.named_parameters())

        if not use_gradient_accumulation or batch_num % NUM_GRADIENT_ACCUMULATION_STEPS == 0:
            optimizer.step()
            bert_qa_module.zero_grad()

        #         print(bert_model_output)
        #         print(bert_model_output[0].size())
        #         print(bert_model_output[1].size())


# eval mode switches off features such as dropout and batch_norm
bert_qa_module.eval()

num_correct_start_index_answers: int = 0
num_correct_end_index_answers: int = 0
total_answers: int = 0

with torch.no_grad():
    for data_item in test_dataloader:
        bert_model_output: Tuple[torch.Tensor, torch.Tensor] = bert_qa_module(input_ids = data_item[0], token_type_ids =
        data_item[1], attention_mask = data_item[4], output_all_encoded_layers = False)

        answer_start_index_batch_as_matrix = data_item[2].unsqueeze(dim = 1).to(device = device)
        answer_end_index_batch_as_matrix = data_item[3].unsqueeze(dim = 1).to(device = device)

        answer_start_index_loss = loss_function(bert_model_output[0], answer_start_index_batch_as_matrix)
        answer_end_index_loss = loss_function(bert_model_output[1], answer_end_index_batch_as_matrix)
        total_loss = answer_start_index_loss + answer_end_index_loss

        answer_start_indices_chosen_by_model = torch.squeeze(torch.topk(bert_model_output[0], 1, dim = 1)[1])
        answer_end_indices_chosen_by_model = torch.squeeze(torch.topk(bert_model_output[1], 1, dim = 1)[1])

        print("batch loss: " + str(total_loss))
        print("answer start indices size: " + str(answer_start_indices_chosen_by_model.size()))
        print("answer end indices size: " + str(answer_end_indices_chosen_by_model.size()))
        print(answer_end_indices_chosen_by_model)

        answer_start_index_comparison_tensor = torch.eq(answer_start_index_batch_as_matrix,
                                                        answer_start_indices_chosen_by_model)
        answer_end_index_comparison_tensor = torch.eq(answer_end_index_batch_as_matrix,
                                                      answer_end_indices_chosen_by_model)

        num_correct_start_index_answers += answer_start_index_comparison_tensor.sum().item()
        num_correct_end_index_answers += answer_end_index_comparison_tensor.sum().item()
        total_answers += (answer_start_indices_chosen_by_model.size()[0] if
                          answer_start_indices_chosen_by_model.dim() > 0 else 1)

print("start index accuracy: " + str(num_correct_start_index_answers / total_answers))
print("end index accuracy: " + str(num_correct_end_index_answers / total_answers))
print("total answers: " + str(total_answers))
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# 100%|██████████| 231508/231508 [00:00<00:00, 966280.16B/s]
# num skipped training instances: 109
# num skipped test instances: 45
# 100%|██████████| 407873900/407873900 [00:46<00:00, 8726328.07B/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# num named parameters: 203
# inside training loop
# output calculation done for batch#: 8000
# total loss: 0.3798036575317383
# param name: bert_model.embeddings.word_embeddings.weight
# average grad: tensor(8.4215e-05, device='cuda:0')
# max grad: tensor(0.1443, device='cuda:0')
# param name: bert_model.embeddings.position_embeddings.weight
# average grad: tensor(0.0033, device='cuda:0')
# max grad: tensor(0.1146, device='cuda:0')
# param name: bert_model.embeddings.token_type_embeddings.weight
# average grad: tensor(0.1375, device='cuda:0')
# max grad: tensor(0.7235, device='cuda:0')
# param name: bert_model.embeddings.LayerNorm.weight
# average grad: tensor(0.0071, device='cuda:0')
# max grad: tensor(0.1251, device='cuda:0')
# param name: bert_model.encoder.layer.0.attention.self.query.weight
# average grad: tensor(0.0007, device='cuda:0')
# max grad: tensor(0.0280, device='cuda:0')
# param name: bert_model.encoder.layer.0.attention.self.key.weight
# average grad: tensor(0.0006, device='cuda:0')
# max grad: tensor(0.0396, device='cuda:0')
# param name: bert_model.encoder.layer.0.attention.self.value.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.0998, device='cuda:0')
# param name: bert_model.encoder.layer.0.attention.output.dense.weight
# average grad: tensor(0.0017, device='cuda:0')
# max grad: tensor(0.0275, device='cuda:0')
# param name: bert_model.encoder.layer.0.attention.output.LayerNorm.weight
# average grad: tensor(0.0057, device='cuda:0')
# max grad: tensor(0.0245, device='cuda:0')
# param name: bert_model.encoder.layer.0.intermediate.dense.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.5129, device='cuda:0')
# param name: bert_model.encoder.layer.0.output.dense.weight
# average grad: tensor(0.0009, device='cuda:0')
# max grad: tensor(0.0444, device='cuda:0')
# param name: bert_model.encoder.layer.0.output.LayerNorm.weight
# average grad: tensor(0.0097, device='cuda:0')
# max grad: tensor(0.5632, device='cuda:0')
# param name: bert_model.encoder.layer.1.attention.self.query.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.0928, device='cuda:0')
# param name: bert_model.encoder.layer.1.attention.self.key.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0862, device='cuda:0')
# param name: bert_model.encoder.layer.1.attention.self.value.weight
# average grad: tensor(0.0019, device='cuda:0')
# max grad: tensor(0.1856, device='cuda:0')
# param name: bert_model.encoder.layer.1.attention.output.dense.weight
# average grad: tensor(0.0019, device='cuda:0')
# max grad: tensor(0.0457, device='cuda:0')
# param name: bert_model.encoder.layer.1.attention.output.LayerNorm.weight
# average grad: tensor(0.0068, device='cuda:0')
# max grad: tensor(0.0373, device='cuda:0')
# param name: bert_model.encoder.layer.1.intermediate.dense.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(1.4685, device='cuda:0')
# param name: bert_model.encoder.layer.1.output.dense.weight
# average grad: tensor(0.0009, device='cuda:0')
# max grad: tensor(0.0432, device='cuda:0')
# param name: bert_model.encoder.layer.1.output.LayerNorm.weight
# average grad: tensor(0.0077, device='cuda:0')
# max grad: tensor(0.2385, device='cuda:0')
# param name: bert_model.encoder.layer.2.attention.self.query.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.0772, device='cuda:0')
# param name: bert_model.encoder.layer.2.attention.self.key.weight
# average grad: tensor(0.0011, device='cuda:0')
# max grad: tensor(0.0604, device='cuda:0')
# param name: bert_model.encoder.layer.2.attention.self.value.weight
# average grad: tensor(0.0023, device='cuda:0')
# max grad: tensor(0.3461, device='cuda:0')
# param name: bert_model.encoder.layer.2.attention.output.dense.weight
# average grad: tensor(0.0022, device='cuda:0')
# max grad: tensor(0.0527, device='cuda:0')
# param name: bert_model.encoder.layer.2.attention.output.LayerNorm.weight
# average grad: tensor(0.0069, device='cuda:0')
# max grad: tensor(0.0317, device='cuda:0')
# param name: bert_model.encoder.layer.2.intermediate.dense.weight
# average grad: tensor(0.0011, device='cuda:0')
# max grad: tensor(0.9590, device='cuda:0')
# param name: bert_model.encoder.layer.2.output.dense.weight
# average grad: tensor(0.0009, device='cuda:0')
# max grad: tensor(0.0771, device='cuda:0')
# param name: bert_model.encoder.layer.2.output.LayerNorm.weight
# average grad: tensor(0.0081, device='cuda:0')
# max grad: tensor(0.2432, device='cuda:0')
# param name: bert_model.encoder.layer.3.attention.self.query.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.1420, device='cuda:0')
# param name: bert_model.encoder.layer.3.attention.self.key.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.0482, device='cuda:0')
# param name: bert_model.encoder.layer.3.attention.self.value.weight
# average grad: tensor(0.0025, device='cuda:0')
# max grad: tensor(0.4744, device='cuda:0')
# param name: bert_model.encoder.layer.3.attention.output.dense.weight
# average grad: tensor(0.0025, device='cuda:0')
# max grad: tensor(0.1519, device='cuda:0')
# param name: bert_model.encoder.layer.3.attention.output.LayerNorm.weight
# average grad: tensor(0.0071, device='cuda:0')
# max grad: tensor(0.0548, device='cuda:0')
# param name: bert_model.encoder.layer.3.intermediate.dense.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.5912, device='cuda:0')
# param name: bert_model.encoder.layer.3.output.dense.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0632, device='cuda:0')
# param name: bert_model.encoder.layer.3.output.LayerNorm.weight
# average grad: tensor(0.0084, device='cuda:0')
# max grad: tensor(0.0760, device='cuda:0')
# param name: bert_model.encoder.layer.4.attention.self.query.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.1308, device='cuda:0')
# param name: bert_model.encoder.layer.4.attention.self.key.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.0844, device='cuda:0')
# param name: bert_model.encoder.layer.4.attention.self.value.weight
# average grad: tensor(0.0028, device='cuda:0')
# max grad: tensor(0.3815, device='cuda:0')
# param name: bert_model.encoder.layer.4.attention.output.dense.weight
# average grad: tensor(0.0029, device='cuda:0')
# max grad: tensor(0.0771, device='cuda:0')
# param name: bert_model.encoder.layer.4.attention.output.LayerNorm.weight
# average grad: tensor(0.0073, device='cuda:0')
# max grad: tensor(0.0468, device='cuda:0')
# param name: bert_model.encoder.layer.4.intermediate.dense.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.4145, device='cuda:0')
# param name: bert_model.encoder.layer.4.output.dense.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0562, device='cuda:0')
# param name: bert_model.encoder.layer.4.output.LayerNorm.weight
# average grad: tensor(0.0084, device='cuda:0')
# max grad: tensor(0.0735, device='cuda:0')
# param name: bert_model.encoder.layer.5.attention.self.query.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.1599, device='cuda:0')
# param name: bert_model.encoder.layer.5.attention.self.key.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.0479, device='cuda:0')
# param name: bert_model.encoder.layer.5.attention.self.value.weight
# average grad: tensor(0.0032, device='cuda:0')
# max grad: tensor(0.3877, device='cuda:0')
# param name: bert_model.encoder.layer.5.attention.output.dense.weight
# average grad: tensor(0.0032, device='cuda:0')
# max grad: tensor(0.0742, device='cuda:0')
# param name: bert_model.encoder.layer.5.attention.output.LayerNorm.weight
# average grad: tensor(0.0076, device='cuda:0')
# max grad: tensor(0.0340, device='cuda:0')
# param name: bert_model.encoder.layer.5.intermediate.dense.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.4169, device='cuda:0')
# param name: bert_model.encoder.layer.5.output.dense.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0697, device='cuda:0')
# param name: bert_model.encoder.layer.5.output.LayerNorm.weight
# average grad: tensor(0.0088, device='cuda:0')
# max grad: tensor(0.1984, device='cuda:0')
# param name: bert_model.encoder.layer.6.attention.self.query.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.1306, device='cuda:0')
# param name: bert_model.encoder.layer.6.attention.self.key.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.0660, device='cuda:0')
# param name: bert_model.encoder.layer.6.attention.self.value.weight
# average grad: tensor(0.0036, device='cuda:0')
# max grad: tensor(0.6095, device='cuda:0')
# param name: bert_model.encoder.layer.6.attention.output.dense.weight
# average grad: tensor(0.0033, device='cuda:0')
# max grad: tensor(0.0520, device='cuda:0')
# param name: bert_model.encoder.layer.6.attention.output.LayerNorm.weight
# average grad: tensor(0.0081, device='cuda:0')
# max grad: tensor(0.1783, device='cuda:0')
# param name: bert_model.encoder.layer.6.intermediate.dense.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.5453, device='cuda:0')
# param name: bert_model.encoder.layer.6.output.dense.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0997, device='cuda:0')
# param name: bert_model.encoder.layer.6.output.LayerNorm.weight
# average grad: tensor(0.0088, device='cuda:0')
# max grad: tensor(0.4401, device='cuda:0')
# param name: bert_model.encoder.layer.7.attention.self.query.weight
# average grad: tensor(0.0009, device='cuda:0')
# max grad: tensor(0.1172, device='cuda:0')
# param name: bert_model.encoder.layer.7.attention.self.key.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.0358, device='cuda:0')
# param name: bert_model.encoder.layer.7.attention.self.value.weight
# average grad: tensor(0.0034, device='cuda:0')
# max grad: tensor(0.3249, device='cuda:0')
# param name: bert_model.encoder.layer.7.attention.output.dense.weight
# average grad: tensor(0.0030, device='cuda:0')
# max grad: tensor(0.0323, device='cuda:0')
# param name: bert_model.encoder.layer.7.attention.output.LayerNorm.weight
# average grad: tensor(0.0079, device='cuda:0')
# max grad: tensor(0.1369, device='cuda:0')
# param name: bert_model.encoder.layer.7.intermediate.dense.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.4527, device='cuda:0')
# param name: bert_model.encoder.layer.7.output.dense.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.1058, device='cuda:0')
# param name: bert_model.encoder.layer.7.output.LayerNorm.weight
# average grad: tensor(0.0083, device='cuda:0')
# max grad: tensor(0.2661, device='cuda:0')
# param name: bert_model.encoder.layer.8.attention.self.query.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.0857, device='cuda:0')
# param name: bert_model.encoder.layer.8.attention.self.key.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.0473, device='cuda:0')
# param name: bert_model.encoder.layer.8.attention.self.value.weight
# average grad: tensor(0.0036, device='cuda:0')
# max grad: tensor(0.3480, device='cuda:0')
# param name: bert_model.encoder.layer.8.attention.output.dense.weight
# average grad: tensor(0.0030, device='cuda:0')
# max grad: tensor(0.0497, device='cuda:0')
# param name: bert_model.encoder.layer.8.attention.output.LayerNorm.weight
# average grad: tensor(0.0072, device='cuda:0')
# max grad: tensor(0.0332, device='cuda:0')
# param name: bert_model.encoder.layer.8.intermediate.dense.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.7306, device='cuda:0')
# param name: bert_model.encoder.layer.8.output.dense.weight
# average grad: tensor(0.0008, device='cuda:0')
# max grad: tensor(0.0417, device='cuda:0')
# param name: bert_model.encoder.layer.8.output.LayerNorm.weight
# average grad: tensor(0.0074, device='cuda:0')
# max grad: tensor(0.3115, device='cuda:0')
# param name: bert_model.encoder.layer.9.attention.self.query.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.1288, device='cuda:0')
# param name: bert_model.encoder.layer.9.attention.self.key.weight
# average grad: tensor(0.0011, device='cuda:0')
# max grad: tensor(0.0400, device='cuda:0')
# param name: bert_model.encoder.layer.9.attention.self.value.weight
# average grad: tensor(0.0023, device='cuda:0')
# max grad: tensor(0.3197, device='cuda:0')
# param name: bert_model.encoder.layer.9.attention.output.dense.weight
# average grad: tensor(0.0021, device='cuda:0')
# max grad: tensor(0.0533, device='cuda:0')
# param name: bert_model.encoder.layer.9.attention.output.LayerNorm.weight
# average grad: tensor(0.0057, device='cuda:0')
# max grad: tensor(0.0443, device='cuda:0')
# param name: bert_model.encoder.layer.9.intermediate.dense.weight
# average grad: tensor(0.0006, device='cuda:0')
# max grad: tensor(0.2869, device='cuda:0')
# param name: bert_model.encoder.layer.9.output.dense.weight
# average grad: tensor(0.0006, device='cuda:0')
# max grad: tensor(0.0512, device='cuda:0')
# param name: bert_model.encoder.layer.9.output.LayerNorm.weight
# average grad: tensor(0.0059, device='cuda:0')
# max grad: tensor(0.0943, device='cuda:0')
# param name: bert_model.encoder.layer.10.attention.self.query.weight
# average grad: tensor(0.0007, device='cuda:0')
# max grad: tensor(0.0610, device='cuda:0')
# param name: bert_model.encoder.layer.10.attention.self.key.weight
# average grad: tensor(0.0007, device='cuda:0')
# max grad: tensor(0.0810, device='cuda:0')
# param name: bert_model.encoder.layer.10.attention.self.value.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.2134, device='cuda:0')
# param name: bert_model.encoder.layer.10.attention.output.dense.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.0339, device='cuda:0')
# param name: bert_model.encoder.layer.10.attention.output.LayerNorm.weight
# average grad: tensor(0.0047, device='cuda:0')
# max grad: tensor(0.1602, device='cuda:0')
# param name: bert_model.encoder.layer.10.intermediate.dense.weight
# average grad: tensor(0.0005, device='cuda:0')
# max grad: tensor(0.3123, device='cuda:0')
# param name: bert_model.encoder.layer.10.output.dense.weight
# average grad: tensor(0.0005, device='cuda:0')
# max grad: tensor(0.0421, device='cuda:0')
# param name: bert_model.encoder.layer.10.output.LayerNorm.weight
# average grad: tensor(0.0046, device='cuda:0')
# max grad: tensor(0.1248, device='cuda:0')
# param name: bert_model.encoder.layer.11.attention.self.query.weight
# average grad: tensor(0.0007, device='cuda:0')
# max grad: tensor(0.0969, device='cuda:0')
# param name: bert_model.encoder.layer.11.attention.self.key.weight
# average grad: tensor(0.0006, device='cuda:0')
# max grad: tensor(0.1219, device='cuda:0')
# param name: bert_model.encoder.layer.11.attention.self.value.weight
# average grad: tensor(0.0009, device='cuda:0')
# max grad: tensor(0.1516, device='cuda:0')
# param name: bert_model.encoder.layer.11.attention.output.dense.weight
# average grad: tensor(0.0008, device='cuda:0')
# max grad: tensor(0.0278, device='cuda:0')
# param name: bert_model.encoder.layer.11.attention.output.LayerNorm.weight
# average grad: tensor(0.0033, device='cuda:0')
# max grad: tensor(0.0336, device='cuda:0')
# param name: bert_model.encoder.layer.11.intermediate.dense.weight
# average grad: tensor(0.0005, device='cuda:0')
# max grad: tensor(0.3060, device='cuda:0')
# param name: bert_model.encoder.layer.11.output.dense.weight
# average grad: tensor(0.0004, device='cuda:0')
# max grad: tensor(0.0281, device='cuda:0')
# param name: bert_model.encoder.layer.11.output.LayerNorm.weight
# average grad: tensor(0.0039, device='cuda:0')
# max grad: tensor(0.0269, device='cuda:0')
# param name: linear_layer_for_answer_start_index.weight
# average grad: tensor(0.0227, device='cuda:0')
# max grad: tensor(0.1031, device='cuda:0')
# param name: linear_layer_for_answer_end_index.weight
# average grad: tensor(0.0188, device='cuda:0')
# max grad: tensor(0.0716, device='cuda:0')
# output calculation done for batch#: 16000
# total loss: 0.3618573844432831
# param name: bert_model.embeddings.word_embeddings.weight
# average grad: tensor(8.7832e-05, device='cuda:0')
# max grad: tensor(0.5195, device='cuda:0')
# param name: bert_model.embeddings.position_embeddings.weight
# average grad: tensor(0.0039, device='cuda:0')
# max grad: tensor(0.5174, device='cuda:0')
# param name: bert_model.embeddings.token_type_embeddings.weight
# average grad: tensor(0.2299, device='cuda:0')
# max grad: tensor(1.5182, device='cuda:0')
# param name: bert_model.embeddings.LayerNorm.weight
# average grad: tensor(0.0120, device='cuda:0')
# max grad: tensor(0.2397, device='cuda:0')
# param name: bert_model.encoder.layer.0.attention.self.query.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.0388, device='cuda:0')
# param name: bert_model.encoder.layer.0.attention.self.key.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.0605, device='cuda:0')
# param name: bert_model.encoder.layer.0.attention.self.value.weight
# average grad: tensor(0.0026, device='cuda:0')
# max grad: tensor(0.1760, device='cuda:0')
# param name: bert_model.encoder.layer.0.attention.output.dense.weight
# average grad: tensor(0.0026, device='cuda:0')
# max grad: tensor(0.0594, device='cuda:0')
# param name: bert_model.encoder.layer.0.attention.output.LayerNorm.weight
# average grad: tensor(0.0090, device='cuda:0')
# max grad: tensor(0.0523, device='cuda:0')
# param name: bert_model.encoder.layer.0.intermediate.dense.weight
# average grad: tensor(0.0016, device='cuda:0')
# max grad: tensor(0.7503, device='cuda:0')
# param name: bert_model.encoder.layer.0.output.dense.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.0809, device='cuda:0')
# param name: bert_model.encoder.layer.0.output.LayerNorm.weight
# average grad: tensor(0.0129, device='cuda:0')
# max grad: tensor(0.1619, device='cuda:0')
# param name: bert_model.encoder.layer.1.attention.self.query.weight
# average grad: tensor(0.0020, device='cuda:0')
# max grad: tensor(0.1398, device='cuda:0')
# param name: bert_model.encoder.layer.1.attention.self.key.weight
# average grad: tensor(0.0021, device='cuda:0')
# max grad: tensor(0.1393, device='cuda:0')
# param name: bert_model.encoder.layer.1.attention.self.value.weight
# average grad: tensor(0.0027, device='cuda:0')
# max grad: tensor(0.4021, device='cuda:0')
# param name: bert_model.encoder.layer.1.attention.output.dense.weight
# average grad: tensor(0.0026, device='cuda:0')
# max grad: tensor(0.0644, device='cuda:0')
# param name: bert_model.encoder.layer.1.attention.output.LayerNorm.weight
# average grad: tensor(0.0085, device='cuda:0')
# max grad: tensor(0.0539, device='cuda:0')
# param name: bert_model.encoder.layer.1.intermediate.dense.weight
# average grad: tensor(0.0015, device='cuda:0')
# max grad: tensor(1.1584, device='cuda:0')
# param name: bert_model.encoder.layer.1.output.dense.weight
# average grad: tensor(0.0011, device='cuda:0')
# max grad: tensor(0.0703, device='cuda:0')
# param name: bert_model.encoder.layer.1.output.LayerNorm.weight
# average grad: tensor(0.0105, device='cuda:0')
# max grad: tensor(1.1060, device='cuda:0')
# param name: bert_model.encoder.layer.2.attention.self.query.weight
# average grad: tensor(0.0015, device='cuda:0')
# max grad: tensor(0.1406, device='cuda:0')
# param name: bert_model.encoder.layer.2.attention.self.key.weight
# average grad: tensor(0.0015, device='cuda:0')
# max grad: tensor(0.3025, device='cuda:0')
# param name: bert_model.encoder.layer.2.attention.self.value.weight
# average grad: tensor(0.0024, device='cuda:0')
# max grad: tensor(0.2392, device='cuda:0')
# param name: bert_model.encoder.layer.2.attention.output.dense.weight
# average grad: tensor(0.0024, device='cuda:0')
# max grad: tensor(0.0513, device='cuda:0')
# param name: bert_model.encoder.layer.2.attention.output.LayerNorm.weight
# average grad: tensor(0.0076, device='cuda:0')
# max grad: tensor(0.0490, device='cuda:0')
# param name: bert_model.encoder.layer.2.intermediate.dense.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.9082, device='cuda:0')
# param name: bert_model.encoder.layer.2.output.dense.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0866, device='cuda:0')
# param name: bert_model.encoder.layer.2.output.LayerNorm.weight
# average grad: tensor(0.0088, device='cuda:0')
# max grad: tensor(0.4898, device='cuda:0')
# param name: bert_model.encoder.layer.3.attention.self.query.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.1058, device='cuda:0')
# param name: bert_model.encoder.layer.3.attention.self.key.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.1397, device='cuda:0')
# param name: bert_model.encoder.layer.3.attention.self.value.weight
# average grad: tensor(0.0026, device='cuda:0')
# max grad: tensor(0.5119, device='cuda:0')
# param name: bert_model.encoder.layer.3.attention.output.dense.weight
# average grad: tensor(0.0025, device='cuda:0')
# max grad: tensor(0.0910, device='cuda:0')
# param name: bert_model.encoder.layer.3.attention.output.LayerNorm.weight
# average grad: tensor(0.0070, device='cuda:0')
# max grad: tensor(0.0740, device='cuda:0')
# param name: bert_model.encoder.layer.3.intermediate.dense.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.9734, device='cuda:0')
# param name: bert_model.encoder.layer.3.output.dense.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0700, device='cuda:0')
# param name: bert_model.encoder.layer.3.output.LayerNorm.weight
# average grad: tensor(0.0088, device='cuda:0')
# max grad: tensor(0.2553, device='cuda:0')
# param name: bert_model.encoder.layer.4.attention.self.query.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.1439, device='cuda:0')
# param name: bert_model.encoder.layer.4.attention.self.key.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.0722, device='cuda:0')
# param name: bert_model.encoder.layer.4.attention.self.value.weight
# average grad: tensor(0.0026, device='cuda:0')
# max grad: tensor(0.6070, device='cuda:0')
# param name: bert_model.encoder.layer.4.attention.output.dense.weight
# average grad: tensor(0.0026, device='cuda:0')
# max grad: tensor(0.0614, device='cuda:0')
# param name: bert_model.encoder.layer.4.attention.output.LayerNorm.weight
# average grad: tensor(0.0071, device='cuda:0')
# max grad: tensor(0.0404, device='cuda:0')
# param name: bert_model.encoder.layer.4.intermediate.dense.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.6264, device='cuda:0')
# param name: bert_model.encoder.layer.4.output.dense.weight
# average grad: tensor(0.0009, device='cuda:0')
# max grad: tensor(0.0687, device='cuda:0')
# param name: bert_model.encoder.layer.4.output.LayerNorm.weight
# average grad: tensor(0.0076, device='cuda:0')
# max grad: tensor(0.1484, device='cuda:0')
# param name: bert_model.encoder.layer.5.attention.self.query.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.0926, device='cuda:0')
# param name: bert_model.encoder.layer.5.attention.self.key.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.0569, device='cuda:0')
# param name: bert_model.encoder.layer.5.attention.self.value.weight
# average grad: tensor(0.0026, device='cuda:0')
# max grad: tensor(0.2869, device='cuda:0')
# param name: bert_model.encoder.layer.5.attention.output.dense.weight
# average grad: tensor(0.0026, device='cuda:0')
# max grad: tensor(0.0548, device='cuda:0')
# param name: bert_model.encoder.layer.5.attention.output.LayerNorm.weight
# average grad: tensor(0.0067, device='cuda:0')
# max grad: tensor(0.0678, device='cuda:0')
# param name: bert_model.encoder.layer.5.intermediate.dense.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.5766, device='cuda:0')
# param name: bert_model.encoder.layer.5.output.dense.weight
# average grad: tensor(0.0009, device='cuda:0')
# max grad: tensor(0.0450, device='cuda:0')
# param name: bert_model.encoder.layer.5.output.LayerNorm.weight
# average grad: tensor(0.0077, device='cuda:0')
# max grad: tensor(0.2105, device='cuda:0')
# param name: bert_model.encoder.layer.6.attention.self.query.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0842, device='cuda:0')
# param name: bert_model.encoder.layer.6.attention.self.key.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.0454, device='cuda:0')
# param name: bert_model.encoder.layer.6.attention.self.value.weight
# average grad: tensor(0.0028, device='cuda:0')
# max grad: tensor(0.3243, device='cuda:0')
# param name: bert_model.encoder.layer.6.attention.output.dense.weight
# average grad: tensor(0.0027, device='cuda:0')
# max grad: tensor(0.0288, device='cuda:0')
# param name: bert_model.encoder.layer.6.attention.output.LayerNorm.weight
# average grad: tensor(0.0070, device='cuda:0')
# max grad: tensor(0.1485, device='cuda:0')
# param name: bert_model.encoder.layer.6.intermediate.dense.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.2978, device='cuda:0')
# param name: bert_model.encoder.layer.6.output.dense.weight
# average grad: tensor(0.0009, device='cuda:0')
# max grad: tensor(0.0476, device='cuda:0')
# param name: bert_model.encoder.layer.6.output.LayerNorm.weight
# average grad: tensor(0.0073, device='cuda:0')
# max grad: tensor(0.1945, device='cuda:0')
# param name: bert_model.encoder.layer.7.attention.self.query.weight
# average grad: tensor(0.0008, device='cuda:0')
# max grad: tensor(0.0598, device='cuda:0')
# param name: bert_model.encoder.layer.7.attention.self.key.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0397, device='cuda:0')
# param name: bert_model.encoder.layer.7.attention.self.value.weight
# average grad: tensor(0.0027, device='cuda:0')
# max grad: tensor(0.1935, device='cuda:0')
# param name: bert_model.encoder.layer.7.attention.output.dense.weight
# average grad: tensor(0.0025, device='cuda:0')
# max grad: tensor(0.0339, device='cuda:0')
# param name: bert_model.encoder.layer.7.attention.output.LayerNorm.weight
# average grad: tensor(0.0066, device='cuda:0')
# max grad: tensor(0.0320, device='cuda:0')
# param name: bert_model.encoder.layer.7.intermediate.dense.weight
# average grad: tensor(0.0011, device='cuda:0')
# max grad: tensor(0.3000, device='cuda:0')
# param name: bert_model.encoder.layer.7.output.dense.weight
# average grad: tensor(0.0008, device='cuda:0')
# max grad: tensor(0.0551, device='cuda:0')
# param name: bert_model.encoder.layer.7.output.LayerNorm.weight
# average grad: tensor(0.0070, device='cuda:0')
# max grad: tensor(0.0609, device='cuda:0')
# param name: bert_model.encoder.layer.8.attention.self.query.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0909, device='cuda:0')
# param name: bert_model.encoder.layer.8.attention.self.key.weight
# average grad: tensor(0.0011, device='cuda:0')
# max grad: tensor(0.0337, device='cuda:0')
# param name: bert_model.encoder.layer.8.attention.self.value.weight
# average grad: tensor(0.0027, device='cuda:0')
# max grad: tensor(0.2349, device='cuda:0')
# param name: bert_model.encoder.layer.8.attention.output.dense.weight
# average grad: tensor(0.0023, device='cuda:0')
# max grad: tensor(0.0318, device='cuda:0')
# param name: bert_model.encoder.layer.8.attention.output.LayerNorm.weight
# average grad: tensor(0.0055, device='cuda:0')
# max grad: tensor(0.0591, device='cuda:0')
# param name: bert_model.encoder.layer.8.intermediate.dense.weight
# average grad: tensor(0.0008, device='cuda:0')
# max grad: tensor(0.5252, device='cuda:0')
# param name: bert_model.encoder.layer.8.output.dense.weight
# average grad: tensor(0.0006, device='cuda:0')
# max grad: tensor(0.0438, device='cuda:0')
# param name: bert_model.encoder.layer.8.output.LayerNorm.weight
# average grad: tensor(0.0056, device='cuda:0')
# max grad: tensor(0.0316, device='cuda:0')
# param name: bert_model.encoder.layer.9.attention.self.query.weight
# average grad: tensor(0.0009, device='cuda:0')
# max grad: tensor(0.1059, device='cuda:0')
# param name: bert_model.encoder.layer.9.attention.self.key.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0340, device='cuda:0')
# param name: bert_model.encoder.layer.9.attention.self.value.weight
# average grad: tensor(0.0017, device='cuda:0')
# max grad: tensor(0.1694, device='cuda:0')
# param name: bert_model.encoder.layer.9.attention.output.dense.weight
# average grad: tensor(0.0015, device='cuda:0')
# max grad: tensor(0.0336, device='cuda:0')
# param name: bert_model.encoder.layer.9.attention.output.LayerNorm.weight
# average grad: tensor(0.0041, device='cuda:0')
# max grad: tensor(0.0496, device='cuda:0')
# param name: bert_model.encoder.layer.9.intermediate.dense.weight
# average grad: tensor(0.0005, device='cuda:0')
# max grad: tensor(0.3784, device='cuda:0')
# param name: bert_model.encoder.layer.9.output.dense.weight
# average grad: tensor(0.0004, device='cuda:0')
# max grad: tensor(0.0555, device='cuda:0')
# param name: bert_model.encoder.layer.9.output.LayerNorm.weight
# average grad: tensor(0.0045, device='cuda:0')
# max grad: tensor(0.2006, device='cuda:0')
# param name: bert_model.encoder.layer.10.attention.self.query.weight
# average grad: tensor(0.0006, device='cuda:0')
# max grad: tensor(0.0808, device='cuda:0')
# param name: bert_model.encoder.layer.10.attention.self.key.weight
# average grad: tensor(0.0007, device='cuda:0')
# max grad: tensor(0.0832, device='cuda:0')
# param name: bert_model.encoder.layer.10.attention.self.value.weight
# average grad: tensor(0.0011, device='cuda:0')
# max grad: tensor(0.1923, device='cuda:0')
# param name: bert_model.encoder.layer.10.attention.output.dense.weight
# average grad: tensor(0.0009, device='cuda:0')
# max grad: tensor(0.0619, device='cuda:0')
# param name: bert_model.encoder.layer.10.attention.output.LayerNorm.weight
# average grad: tensor(0.0034, device='cuda:0')
# max grad: tensor(0.3815, device='cuda:0')
# param name: bert_model.encoder.layer.10.intermediate.dense.weight
# average grad: tensor(0.0003, device='cuda:0')
# max grad: tensor(0.1148, device='cuda:0')
# param name: bert_model.encoder.layer.10.output.dense.weight
# average grad: tensor(0.0003, device='cuda:0')
# max grad: tensor(0.0974, device='cuda:0')
# param name: bert_model.encoder.layer.10.output.LayerNorm.weight
# average grad: tensor(0.0035, device='cuda:0')
# max grad: tensor(0.1832, device='cuda:0')
# param name: bert_model.encoder.layer.11.attention.self.query.weight
# average grad: tensor(0.0005, device='cuda:0')
# max grad: tensor(0.0757, device='cuda:0')
# param name: bert_model.encoder.layer.11.attention.self.key.weight
# average grad: tensor(0.0005, device='cuda:0')
# max grad: tensor(0.0575, device='cuda:0')
# param name: bert_model.encoder.layer.11.attention.self.value.weight
# average grad: tensor(0.0007, device='cuda:0')
# max grad: tensor(0.1241, device='cuda:0')
# param name: bert_model.encoder.layer.11.attention.output.dense.weight
# average grad: tensor(0.0005, device='cuda:0')
# max grad: tensor(0.0179, device='cuda:0')
# param name: bert_model.encoder.layer.11.attention.output.LayerNorm.weight
# average grad: tensor(0.0025, device='cuda:0')
# max grad: tensor(0.1591, device='cuda:0')
# param name: bert_model.encoder.layer.11.intermediate.dense.weight
# average grad: tensor(0.0004, device='cuda:0')
# max grad: tensor(0.2593, device='cuda:0')
# param name: bert_model.encoder.layer.11.output.dense.weight
# average grad: tensor(0.0003, device='cuda:0')
# max grad: tensor(0.0204, device='cuda:0')
# param name: bert_model.encoder.layer.11.output.LayerNorm.weight
# average grad: tensor(0.0029, device='cuda:0')
# max grad: tensor(0.0197, device='cuda:0')
# param name: linear_layer_for_answer_start_index.weight
# average grad: tensor(0.0165, device='cuda:0')
# max grad: tensor(0.0786, device='cuda:0')
# param name: linear_layer_for_answer_end_index.weight
# average grad: tensor(0.0142, device='cuda:0')
# max grad: tensor(0.0565, device='cuda:0')
#  50%|█████     | 1/2 [24:10<24:10, 1450.52s/it]
# inside training loop
# output calculation done for batch#: 24000
# total loss: 0.6228408217430115
# param name: bert_model.embeddings.word_embeddings.weight
# average grad: tensor(8.4514e-05, device='cuda:0')
# max grad: tensor(0.1897, device='cuda:0')
# param name: bert_model.embeddings.position_embeddings.weight
# average grad: tensor(0.0034, device='cuda:0')
# max grad: tensor(0.1378, device='cuda:0')
# param name: bert_model.embeddings.token_type_embeddings.weight
# average grad: tensor(0.1335, device='cuda:0')
# max grad: tensor(0.7630, device='cuda:0')
# param name: bert_model.embeddings.LayerNorm.weight
# average grad: tensor(0.0069, device='cuda:0')
# max grad: tensor(0.1466, device='cuda:0')
# param name: bert_model.encoder.layer.0.attention.self.query.weight
# average grad: tensor(0.0007, device='cuda:0')
# max grad: tensor(0.0584, device='cuda:0')
# param name: bert_model.encoder.layer.0.attention.self.key.weight
# average grad: tensor(0.0007, device='cuda:0')
# max grad: tensor(0.0379, device='cuda:0')
# param name: bert_model.encoder.layer.0.attention.self.value.weight
# average grad: tensor(0.0016, device='cuda:0')
# max grad: tensor(0.2168, device='cuda:0')
# param name: bert_model.encoder.layer.0.attention.output.dense.weight
# average grad: tensor(0.0018, device='cuda:0')
# max grad: tensor(0.0314, device='cuda:0')
# param name: bert_model.encoder.layer.0.attention.output.LayerNorm.weight
# average grad: tensor(0.0054, device='cuda:0')
# max grad: tensor(0.0255, device='cuda:0')
# param name: bert_model.encoder.layer.0.intermediate.dense.weight
# average grad: tensor(0.0011, device='cuda:0')
# max grad: tensor(0.7198, device='cuda:0')
# param name: bert_model.encoder.layer.0.output.dense.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0384, device='cuda:0')
# param name: bert_model.encoder.layer.0.output.LayerNorm.weight
# average grad: tensor(0.0084, device='cuda:0')
# max grad: tensor(0.1568, device='cuda:0')
# param name: bert_model.encoder.layer.1.attention.self.query.weight
# average grad: tensor(0.0011, device='cuda:0')
# max grad: tensor(0.0677, device='cuda:0')
# param name: bert_model.encoder.layer.1.attention.self.key.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0689, device='cuda:0')
# param name: bert_model.encoder.layer.1.attention.self.value.weight
# average grad: tensor(0.0020, device='cuda:0')
# max grad: tensor(0.1949, device='cuda:0')
# param name: bert_model.encoder.layer.1.attention.output.dense.weight
# average grad: tensor(0.0021, device='cuda:0')
# max grad: tensor(0.0465, device='cuda:0')
# param name: bert_model.encoder.layer.1.attention.output.LayerNorm.weight
# average grad: tensor(0.0067, device='cuda:0')
# max grad: tensor(0.0395, device='cuda:0')
# param name: bert_model.encoder.layer.1.intermediate.dense.weight
# average grad: tensor(0.0011, device='cuda:0')
# max grad: tensor(0.8040, device='cuda:0')
# param name: bert_model.encoder.layer.1.output.dense.weight
# average grad: tensor(0.0009, device='cuda:0')
# max grad: tensor(0.0424, device='cuda:0')
# param name: bert_model.encoder.layer.1.output.LayerNorm.weight
# average grad: tensor(0.0081, device='cuda:0')
# max grad: tensor(0.2342, device='cuda:0')
# param name: bert_model.encoder.layer.2.attention.self.query.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.1199, device='cuda:0')
# param name: bert_model.encoder.layer.2.attention.self.key.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.0395, device='cuda:0')
# param name: bert_model.encoder.layer.2.attention.self.value.weight
# average grad: tensor(0.0025, device='cuda:0')
# max grad: tensor(0.3972, device='cuda:0')
# param name: bert_model.encoder.layer.2.attention.output.dense.weight
# average grad: tensor(0.0024, device='cuda:0')
# max grad: tensor(0.0603, device='cuda:0')
# param name: bert_model.encoder.layer.2.attention.output.LayerNorm.weight
# average grad: tensor(0.0073, device='cuda:0')
# max grad: tensor(0.0403, device='cuda:0')
# param name: bert_model.encoder.layer.2.intermediate.dense.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(1.6277, device='cuda:0')
# param name: bert_model.encoder.layer.2.output.dense.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0671, device='cuda:0')
# param name: bert_model.encoder.layer.2.output.LayerNorm.weight
# average grad: tensor(0.0087, device='cuda:0')
# max grad: tensor(0.2921, device='cuda:0')
# param name: bert_model.encoder.layer.3.attention.self.query.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.1285, device='cuda:0')
# param name: bert_model.encoder.layer.3.attention.self.key.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.0656, device='cuda:0')
# param name: bert_model.encoder.layer.3.attention.self.value.weight
# average grad: tensor(0.0028, device='cuda:0')
# max grad: tensor(0.4986, device='cuda:0')
# param name: bert_model.encoder.layer.3.attention.output.dense.weight
# average grad: tensor(0.0027, device='cuda:0')
# max grad: tensor(0.1290, device='cuda:0')
# param name: bert_model.encoder.layer.3.attention.output.LayerNorm.weight
# average grad: tensor(0.0074, device='cuda:0')
# max grad: tensor(0.0781, device='cuda:0')
# param name: bert_model.encoder.layer.3.intermediate.dense.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.8683, device='cuda:0')
# param name: bert_model.encoder.layer.3.output.dense.weight
# average grad: tensor(0.0011, device='cuda:0')
# max grad: tensor(0.0657, device='cuda:0')
# param name: bert_model.encoder.layer.3.output.LayerNorm.weight
# average grad: tensor(0.0092, device='cuda:0')
# max grad: tensor(0.1873, device='cuda:0')
# param name: bert_model.encoder.layer.4.attention.self.query.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.1292, device='cuda:0')
# param name: bert_model.encoder.layer.4.attention.self.key.weight
# average grad: tensor(0.0015, device='cuda:0')
# max grad: tensor(0.1051, device='cuda:0')
# param name: bert_model.encoder.layer.4.attention.self.value.weight
# average grad: tensor(0.0030, device='cuda:0')
# max grad: tensor(0.7317, device='cuda:0')
# param name: bert_model.encoder.layer.4.attention.output.dense.weight
# average grad: tensor(0.0030, device='cuda:0')
# max grad: tensor(0.0927, device='cuda:0')
# param name: bert_model.encoder.layer.4.attention.output.LayerNorm.weight
# average grad: tensor(0.0079, device='cuda:0')
# max grad: tensor(0.0593, device='cuda:0')
# param name: bert_model.encoder.layer.4.intermediate.dense.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.6504, device='cuda:0')
# param name: bert_model.encoder.layer.4.output.dense.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.1092, device='cuda:0')
# param name: bert_model.encoder.layer.4.output.LayerNorm.weight
# average grad: tensor(0.0093, device='cuda:0')
# max grad: tensor(0.2240, device='cuda:0')
# param name: bert_model.encoder.layer.5.attention.self.query.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.1436, device='cuda:0')
# param name: bert_model.encoder.layer.5.attention.self.key.weight
# average grad: tensor(0.0015, device='cuda:0')
# max grad: tensor(0.0854, device='cuda:0')
# param name: bert_model.encoder.layer.5.attention.self.value.weight
# average grad: tensor(0.0033, device='cuda:0')
# max grad: tensor(0.5427, device='cuda:0')
# param name: bert_model.encoder.layer.5.attention.output.dense.weight
# average grad: tensor(0.0033, device='cuda:0')
# max grad: tensor(0.0827, device='cuda:0')
# param name: bert_model.encoder.layer.5.attention.output.LayerNorm.weight
# average grad: tensor(0.0083, device='cuda:0')
# max grad: tensor(0.0403, device='cuda:0')
# param name: bert_model.encoder.layer.5.intermediate.dense.weight
# average grad: tensor(0.0015, device='cuda:0')
# max grad: tensor(0.5265, device='cuda:0')
# param name: bert_model.encoder.layer.5.output.dense.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.0393, device='cuda:0')
# param name: bert_model.encoder.layer.5.output.LayerNorm.weight
# average grad: tensor(0.0100, device='cuda:0')
# max grad: tensor(0.2264, device='cuda:0')
# param name: bert_model.encoder.layer.6.attention.self.query.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.1256, device='cuda:0')
# param name: bert_model.encoder.layer.6.attention.self.key.weight
# average grad: tensor(0.0015, device='cuda:0')
# max grad: tensor(0.1026, device='cuda:0')
# param name: bert_model.encoder.layer.6.attention.self.value.weight
# average grad: tensor(0.0036, device='cuda:0')
# max grad: tensor(0.4637, device='cuda:0')
# param name: bert_model.encoder.layer.6.attention.output.dense.weight
# average grad: tensor(0.0034, device='cuda:0')
# max grad: tensor(0.0700, device='cuda:0')
# param name: bert_model.encoder.layer.6.attention.output.LayerNorm.weight
# average grad: tensor(0.0089, device='cuda:0')
# max grad: tensor(0.0514, device='cuda:0')
# param name: bert_model.encoder.layer.6.intermediate.dense.weight
# average grad: tensor(0.0015, device='cuda:0')
# max grad: tensor(0.7065, device='cuda:0')
# param name: bert_model.encoder.layer.6.output.dense.weight
# average grad: tensor(0.0011, device='cuda:0')
# max grad: tensor(0.0563, device='cuda:0')
# param name: bert_model.encoder.layer.6.output.LayerNorm.weight
# average grad: tensor(0.0100, device='cuda:0')
# max grad: tensor(0.3362, device='cuda:0')
# param name: bert_model.encoder.layer.7.attention.self.query.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0854, device='cuda:0')
# param name: bert_model.encoder.layer.7.attention.self.key.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.0351, device='cuda:0')
# param name: bert_model.encoder.layer.7.attention.self.value.weight
# average grad: tensor(0.0035, device='cuda:0')
# max grad: tensor(0.2553, device='cuda:0')
# param name: bert_model.encoder.layer.7.attention.output.dense.weight
# average grad: tensor(0.0031, device='cuda:0')
# max grad: tensor(0.0384, device='cuda:0')
# param name: bert_model.encoder.layer.7.attention.output.LayerNorm.weight
# average grad: tensor(0.0084, device='cuda:0')
# max grad: tensor(0.1479, device='cuda:0')
# param name: bert_model.encoder.layer.7.intermediate.dense.weight
# average grad: tensor(0.0014, device='cuda:0')
# max grad: tensor(0.5181, device='cuda:0')
# param name: bert_model.encoder.layer.7.output.dense.weight
# average grad: tensor(0.0010, device='cuda:0')
# max grad: tensor(0.0771, device='cuda:0')
# param name: bert_model.encoder.layer.7.output.LayerNorm.weight
# average grad: tensor(0.0089, device='cuda:0')
# max grad: tensor(0.2685, device='cuda:0')
# param name: bert_model.encoder.layer.8.attention.self.query.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.1249, device='cuda:0')
# param name: bert_model.encoder.layer.8.attention.self.key.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.0374, device='cuda:0')
# param name: bert_model.encoder.layer.8.attention.self.value.weight
# average grad: tensor(0.0035, device='cuda:0')
# max grad: tensor(0.3039, device='cuda:0')
# param name: bert_model.encoder.layer.8.attention.output.dense.weight
# average grad: tensor(0.0029, device='cuda:0')
# max grad: tensor(0.0373, device='cuda:0')
# param name: bert_model.encoder.layer.8.attention.output.LayerNorm.weight
# average grad: tensor(0.0074, device='cuda:0')
# max grad: tensor(0.1447, device='cuda:0')
# param name: bert_model.encoder.layer.8.intermediate.dense.weight
# average grad: tensor(0.0009, device='cuda:0')
# max grad: tensor(0.5273, device='cuda:0')
# param name: bert_model.encoder.layer.8.output.dense.weight
# average grad: tensor(0.0008, device='cuda:0')
# max grad: tensor(0.0358, device='cuda:0')
# param name: bert_model.encoder.layer.8.output.LayerNorm.weight
# average grad: tensor(0.0077, device='cuda:0')
# max grad: tensor(0.3116, device='cuda:0')
# param name: bert_model.encoder.layer.9.attention.self.query.weight
# average grad: tensor(0.0011, device='cuda:0')
# max grad: tensor(0.2806, device='cuda:0')
# param name: bert_model.encoder.layer.9.attention.self.key.weight
# average grad: tensor(0.0012, device='cuda:0')
# max grad: tensor(0.0638, device='cuda:0')
# param name: bert_model.encoder.layer.9.attention.self.value.weight
# average grad: tensor(0.0021, device='cuda:0')
# max grad: tensor(0.2977, device='cuda:0')
# param name: bert_model.encoder.layer.9.attention.output.dense.weight
# average grad: tensor(0.0018, device='cuda:0')
# max grad: tensor(0.0298, device='cuda:0')
# param name: bert_model.encoder.layer.9.attention.output.LayerNorm.weight
# average grad: tensor(0.0053, device='cuda:0')
# max grad: tensor(0.0466, device='cuda:0')
# param name: bert_model.encoder.layer.9.intermediate.dense.weight
# average grad: tensor(0.0006, device='cuda:0')
# max grad: tensor(0.2752, device='cuda:0')
# param name: bert_model.encoder.layer.9.output.dense.weight
# average grad: tensor(0.0005, device='cuda:0')
# max grad: tensor(0.0435, device='cuda:0')
# param name: bert_model.encoder.layer.9.output.LayerNorm.weight
# average grad: tensor(0.0054, device='cuda:0')
# max grad: tensor(0.0739, device='cuda:0')
# param name: bert_model.encoder.layer.10.attention.self.query.weight
# average grad: tensor(0.0007, device='cuda:0')
# max grad: tensor(0.1573, device='cuda:0')
# param name: bert_model.encoder.layer.10.attention.self.key.weight
# average grad: tensor(0.0008, device='cuda:0')
# max grad: tensor(0.2174, device='cuda:0')
# param name: bert_model.encoder.layer.10.attention.self.value.weight
# average grad: tensor(0.0013, device='cuda:0')
# max grad: tensor(0.1657, device='cuda:0')
# param name: bert_model.encoder.layer.10.attention.output.dense.weight
# average grad: tensor(0.0011, device='cuda:0')
# max grad: tensor(0.0547, device='cuda:0')
# param name: bert_model.encoder.layer.10.attention.output.LayerNorm.weight
# average grad: tensor(0.0041, device='cuda:0')
# max grad: tensor(0.0424, device='cuda:0')
# param name: bert_model.encoder.layer.10.intermediate.dense.weight
# average grad: tensor(0.0004, device='cuda:0')
# max grad: tensor(0.1408, device='cuda:0')
# param name: bert_model.encoder.layer.10.output.dense.weight
# average grad: tensor(0.0004, device='cuda:0')
# max grad: tensor(0.2179, device='cuda:0')
# param name: bert_model.encoder.layer.10.output.LayerNorm.weight
# average grad: tensor(0.0056, device='cuda:0')
# max grad: tensor(0.9884, device='cuda:0')
# param name: bert_model.encoder.layer.11.attention.self.query.weight
# average grad: tensor(0.0006, device='cuda:0')
# max grad: tensor(0.1037, device='cuda:0')
# param name: bert_model.encoder.layer.11.attention.self.key.weight
# average grad: tensor(0.0006, device='cuda:0')
# max grad: tensor(0.1566, device='cuda:0')
# param name: bert_model.encoder.layer.11.attention.self.value.weight
# average grad: tensor(0.0009, device='cuda:0')
# max grad: tensor(0.2479, device='cuda:0')
# param name: bert_model.encoder.layer.11.attention.output.dense.weight
# average grad: tensor(0.0008, device='cuda:0')
# max grad: tensor(0.0285, device='cuda:0')
# param name: bert_model.encoder.layer.11.attention.output.LayerNorm.weight
# average grad: tensor(0.0037, device='cuda:0')
# max grad: tensor(0.1076, device='cuda:0')
# param name: bert_model.encoder.layer.11.intermediate.dense.weight
# average grad: tensor(0.0005, device='cuda:0')
# max grad: tensor(0.4441, device='cuda:0')
# param name: bert_model.encoder.layer.11.output.dense.weight
# average grad: tensor(0.0004, device='cuda:0')
# max grad: tensor(0.0206, device='cuda:0')
# param name: bert_model.encoder.layer.11.output.LayerNorm.weight
# average grad: tensor(0.0047, device='cuda:0')
# max grad: tensor(0.0487, device='cuda:0')
# param name: linear_layer_for_answer_start_index.weight
# average grad: tensor(0.0195, device='cuda:0')
# max grad: tensor(0.1667, device='cuda:0')
# param name: linear_layer_for_answer_end_index.weight
# average grad: tensor(0.0293, device='cuda:0')
# max grad: tensor(0.2565, device='cuda:0')
# output calculation done for batch#: 32000
# total loss: 0.3208230137825012
# param name: bert_model.embeddings.word_embeddings.weight
# average grad: tensor(5.8987e-05, device='cuda:0')
# max grad: tensor(0.1202, device='cuda:0')
# param name: bert_model.embeddings.position_embeddings.weight
# average grad: tensor(0.0023, device='cuda:0')
# ...
# batch loss: tensor(1.6788, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 17,  27,  36,  70, 120], device='cuda:0')
# batch loss: tensor(1.0032, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 22,  45,  96, 124,  17], device='cuda:0')
# batch loss: tensor(0.1734, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 40,  85, 118, 137,  15], device='cuda:0')
# batch loss: tensor(1.8652, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([66, 59, 63, 73, 14], device='cuda:0')
# batch loss: tensor(1.5194, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([13, 31, 47, 82, 40], device='cuda:0')
# batch loss: tensor(1.2575, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 28,  33, 102, 151,  50], device='cuda:0')
# batch loss: tensor(0.6963, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 56,  66, 106, 124,  31], device='cuda:0')
# batch loss: tensor(0.6495, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([34, 61, 80, 95, 18], device='cuda:0')
# batch loss: tensor(0.6948, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 46,  54,  90, 103,  17], device='cuda:0')
# batch loss: tensor(0.9362, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 50,  51,  70, 106,  13], device='cuda:0')
# batch loss: tensor(2.1778, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([  8,  57,  68, 129,  59], device='cuda:0')
# batch loss: tensor(0.6609, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 63,  77, 118, 144,  30], device='cuda:0')
# batch loss: tensor(0.7135, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 51,  48, 106, 128,  25], device='cuda:0')
# batch loss: tensor(0.7926, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 35,  62,  69, 117,  14], device='cuda:0')
# batch loss: tensor(2.8486, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([44, 90, 97, 19, 51], device='cuda:0')
# batch loss: tensor(6.0362, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 95,  17,  54, 126, 134], device='cuda:0')
# batch loss: tensor(5.3501, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([155,  51,  61,  23, 143], device='cuda:0')
# batch loss: tensor(5.2994, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 40,  82,  24,  58, 128], device='cuda:0')
# batch loss: tensor(1.9573, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([134, 178,  71,  99, 111], device='cuda:0')
# batch loss: tensor(3.5560, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([104,  15,  25, 109,  17], device='cuda:0')
# batch loss: tensor(2.6787, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([30, 46, 25, 41, 94], device='cuda:0')
# batch loss: tensor(3.8434, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([134,  36, 110, 120,  23], device='cuda:0')
# batch loss: tensor(6.9154, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 32,  42,  44,  25, 164], device='cuda:0')
# batch loss: tensor(3.9092, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 41,  79, 127, 128,  36], device='cuda:0')
# batch loss: tensor(4.4770, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 66, 111,  13,  27,  80], device='cuda:0')
# batch loss: tensor(2.4237, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([118, 169,  30,  48,  70], device='cuda:0')
# batch loss: tensor(6.4094, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 80,  30, 114, 155, 164], device='cuda:0')
# batch loss: tensor(1.9637, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 21, 120, 156,  55, 198], device='cuda:0')
# batch loss: tensor(3.5781, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 31,  49,  27, 128,  31], device='cuda:0')
# batch loss: tensor(1.5760, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 67, 103, 132,  16,  59], device='cuda:0')
# batch loss: tensor(7.8915, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 95, 115,  93,  40, 145], device='cuda:0')
# batch loss: tensor(6.8482, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([105, 115, 177,  49, 104], device='cuda:0')
# batch loss: tensor(6.1203, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 90, 109,  31,  51,  95], device='cuda:0')
# batch loss: tensor(7.0133, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 52,  13,  51,  82, 120], device='cuda:0')
# batch loss: tensor(8.2376, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 28,  41,  94, 102,  36], device='cuda:0')
# batch loss: tensor(5.9090, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([109, 167, 190, 202,  11], device='cuda:0')
# batch loss: tensor(5.1316, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 62, 205,  20,  33,  67], device='cuda:0')
# batch loss: tensor(1.1723, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 84,  33,  75, 119,  74], device='cuda:0')
# batch loss: tensor(4.0425, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 56,  98, 115,  30,  94], device='cuda:0')
# batch loss: tensor(1.0366, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([132, 150,  38,  56,  68], device='cuda:0')
# batch loss: tensor(5.6997, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([140,  12,  59, 143,  58], device='cuda:0')
# batch loss: tensor(5.9121, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 58, 203,  15,  57, 105], device='cuda:0')
# batch loss: tensor(8.6785, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([132,  33,  37,  88,  84], device='cuda:0')
# batch loss: tensor(3.8813, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 58,  72, 115,  33,  74], device='cuda:0')
# batch loss: tensor(5.0235, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 96, 117,  26,  83,  31], device='cuda:0')
# batch loss: tensor(6.7183, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 29,  56, 101,  74,  24], device='cuda:0')
# batch loss: tensor(2.2408, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([41, 70, 96, 14, 39], device='cuda:0')
# batch loss: tensor(2.1001, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 70,  33,  53,  87, 133], device='cuda:0')
# batch loss: tensor(3.8514, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([167,  19,  79, 126, 150], device='cuda:0')
# batch loss: tensor(4.7578, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([127,  38,  57,  89,  90], device='cuda:0')
# batch loss: tensor(0.6858, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([128,   8,  33,  49,  88], device='cuda:0')
# batch loss: tensor(1.2963, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([133,  31,  36,  61,  59], device='cuda:0')
# batch loss: tensor(0.8330, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([126,  23,  61,  76, 169], device='cuda:0')
# batch loss: tensor(0.9189, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([252,  33, 102, 174, 231], device='cuda:0')
# batch loss: tensor(1.0709, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 15,  47,  82, 132, 233], device='cuda:0')
# batch loss: tensor(1.5995, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 28,  42,  82,  80, 157], device='cuda:0')
# batch loss: tensor(3.3397, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 20,  38,  70, 110,  98], device='cuda:0')
# batch loss: tensor(1.4645, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 24, 119,  25,  59,  91], device='cuda:0')
# batch loss: tensor(2.0935, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 68,  44,  64, 252, 134], device='cuda:0')
# batch loss: tensor(4.9541, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([164,  21,  48,  74, 180], device='cuda:0')
# batch loss: tensor(1.4594, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 83,  33,  51,  69, 114], device='cuda:0')
# batch loss: tensor(1.7395, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([224,  44,  42,  77, 102], device='cuda:0')
# batch loss: tensor(5.1421, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 33,  73,  82, 100, 160], device='cuda:0')
# batch loss: tensor(3.9001, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 12,  69,  79, 195, 193], device='cuda:0')
# batch loss: tensor(0.3143, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 21,  50, 111,  90,  46], device='cuda:0')
# batch loss: tensor(1.2661, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 54, 130,  46,  23,  58], device='cuda:0')
# batch loss: tensor(6.7182, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 61,  82, 187, 119,  34], device='cuda:0')
# batch loss: tensor(0.4103, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 54,  88, 235, 253,  22], device='cuda:0')
# batch loss: tensor(1.0150, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 27,  59,  71, 111,  33], device='cuda:0')
# batch loss: tensor(1.8070, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 91, 280, 142,  24,  62], device='cuda:0')
# batch loss: tensor(3.0646, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([113, 129, 155,  28,  52], device='cuda:0')
# batch loss: tensor(6.1815, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 80, 112,  19,  66,  64], device='cuda:0')
# batch loss: tensor(0.1821, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([111,  19,  51,  77,  72], device='cuda:0')
# batch loss: tensor(3.7059, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 81,  14, 146, 251, 116], device='cuda:0')
# batch loss: tensor(1.9349, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([42, 17, 65, 96, 29], device='cuda:0')
# batch loss: tensor(0.7646, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([24, 42, 63, 28, 25], device='cuda:0')
# batch loss: tensor(0.6651, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 75,  76, 105,  75,  45], device='cuda:0')
# batch loss: tensor(1.0120, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 54, 120, 143,  16,  24], device='cuda:0')
# batch loss: tensor(4.7664, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 38,  75, 131,  13,  17], device='cuda:0')
# batch loss: tensor(1.6093, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 38,  73, 125,  14,  36], device='cuda:0')
# batch loss: tensor(1.5891, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([42, 71, 16, 46, 69], device='cuda:0')
# batch loss: tensor(1.0289, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([219, 134,  29,  39, 116], device='cuda:0')
# batch loss: tensor(5.4240, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([64, 52, 81, 31, 33], device='cuda:0')
# batch loss: tensor(3.1170, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 33,  15,  86,  90, 177], device='cuda:0')
# batch loss: tensor(0.5619, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([ 86, 182, 179, 163,  32], device='cuda:0')
# batch loss: tensor(2.0205, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([34, 50, 72, 77, 25], device='cuda:0')
# batch loss: tensor(0.3804, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([30, 58, 98, 36, 43], device='cuda:0')
# batch loss: tensor(2.4897, device='cuda:0')
# answer start indices size: torch.Size([5])
# answer end indices size: torch.Size([5])
# tensor([44, 76, 44, 14, 44], device='cuda:0')
# batch loss: tensor(8.4045, device='cuda:0')
# answer start indices size: torch.Size([3])
# answer end indices size: torch.Size([3])
# tensor([81, 84, 81], device='cuda:0')
# start index accuracy: 0.6848546659867415
# end index accuracy: 0.7146013938466769
# total answers: 5883
